# %%
import solomon.examples as ex
import solomon.modular as smod
def primes_method5(n):
    out = list()
    sieve = [True] * (n+1)
    for p in range(2, n+1):
        if (sieve[p]):
            out.append(p)
            for i in range(p, n+1, p):
                sieve[i] = False
    return out

# %%
(S,rep,orb) = ex.alternating_genus_1(7)
primes = primes_method5(5)
mod_reps_orbs = smod.mod_rep_orbs(rep,orb, lst=primes)
mod_orbs = [(primes[i],orb) for (i,(_,orb)) in enumerate(mod_reps_orbs)]

# %%
mod_orbs[0][1].advance_until(N=200)
len(mod_orbs[0][1].digraph.nodes)
# Out:
# 728

# %%
advanced_orbs = smod.advance_all_orbs([orb for (_, orb) in mod_orbs])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 advanced_orbs = smod.advance_all_orbs([orb for (_, orb) in mod_orbs])
#       2 mod_orbs[0]
#
# File ~/Documents/Repos/solomon/src/solomon/modular.py:16, in advance_all_orbs(orbs, printit)
#      14 if not(printit):
#      15     for orb in orbs:
# ---> 16         orb.advance_until()
#      17 else:
#      18     for p,orb in orbs:
#
# File ~/Documents/Repos/solomon/src/solomon/orbit_graph.py:108, in OrbitGraph.advance_until(self, N)
#     106 this_size = -1
#     107 while last_size != this_size:
# --> 108     self.advance()
#     109     last_size = this_size
#     110     this_size = len(self.digraph.nodes())
#
# File ~/Documents/Repos/solomon/src/solomon/orbit_graph.py:101, in OrbitGraph.advance(self)
#      98 lst2 = list(self.digraph.in_degree())
#     100 self.advance_lst_dir(lst1, self.DIR.FORWARD)
# --> 101 self.advance_lst_dir(lst2, self.DIR.BACK)
#
# File ~/Documents/Repos/solomon/src/solomon/orbit_graph.py:86, in OrbitGraph.advance_lst_dir(self, inp_lst, direction, par)
#      84             self.add_all_nodes_edges(to_add)
#      85 for node in lst:
# ---> 86     self.advance_node_dir(node,direction)
#
# File ~/Documents/Repos/solomon/src/solomon/orbit_graph.py:62, in OrbitGraph.advance_node_dir(self, n, direction, par)
#      60 else:
#      61     for g in self.gens:
# ---> 62         self.advance_node_gen(n,g,direction)
#
# File ~/Documents/Repos/solomon/src/solomon/orbit_graph.py:48, in OrbitGraph.advance_node_gen(self, n, g, direction)
#      47 def advance_node_gen(self, n, g, direction):
# ---> 48     (node,edge) = self.advance_node_gen_pure(n,g,direction)
#      49     if not(self.digraph.has_edge(*edge)):
#      50         self.digraph.add_node(node)
#
# File ~/Documents/Repos/solomon/src/solomon/orbit_graph.py:35, in OrbitGraph.advance_node_gen_pure(self, n, g, direction)
#      33     return (m, (n,m,str(g)))
#      34 elif direction == self.DIR.BACK:
# ---> 35     m = self.action(g**int(-1),n)
#      36     return (m,(m,n,str(g)))
#      37 else:
#
# File ~/Documents/Repos/solomon/src/solomon/monodromy_rep.py:21, in MonodromyRep.action(cls, mclass, rep)
#      18 @classmethod
#      19 def action(cls, mclass, rep):
#      20     assert isinstance(rep, MonodromyRep), "Action is Only for Monodromy Reps"
# ---> 21     return rep.twist(mclass)
#
# File ~/Documents/Repos/solomon/src/solomon/monodromy_rep.py:39, in MonodromyRep.twist(self, mclass, debug)
#      36 assert isinstance(mclass,FreeGrpElement), "Currently for Free base Groups, braids must be passed in directly"
#      38 # This workaround is because technically self.domain is a FP group, not a free group
# ---> 39 mclass_hom = mclass.artin_hom(self.domain)
#      40 workaround_lst = [self.domain(mclass_hom(x).Tietze()) for x  in self.domain.gens]
#      42 new_map = [self(a) for a in workaround_lst]
#
# File ~/Documents/Repos/solomon/src/solomon/surface_group.py:86, in FreeGrpElement.artin_hom(self, grp)
#      84 res = grp.identity_hom()
#      85 for x in individual_actions:
# ---> 86     res = res.then(x)
#      87 return res
#
# File ~/Documents/Repos/solomon/src/solomon/surface_group.py:117, in FreeGrpHom.then(self, other)
#     115 def then(self,other):
#     116     assert isinstance(other,FreeGrpHom)
# --> 117     new_lst = [other(x) for x in self.map_gens]
#     118     return FreeGrpHom(new_lst)
#
# File ~/Documents/Repos/solomon/src/solomon/surface_group.py:112, in FreeGrpHom.__call__(self, other, power)
#     110         result = to_multiply * result
#     111     else:
# --> 112         result = result * to_multiply
#     113 return result
#
# File ~/Documents/Repos/solomon/src/solomon/surface_group.py:56, in FreeGrpElement.__mul__(self, other)
#      54 def __mul__(self,other):
#      55     assert isinstance(other,FreeGrpElement) and self.parent == other.parent, "Group Op Not Defined"
# ---> 56     return FreeGrpElement(self.Tietze() + other.Tietze(), self.parent)
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
xys = np.array([[primes[i],len(orb.digraph.nodes)] for i,orb in enumerate(advanced_orbs)])



# Sample data
X = np.array([[x] for x in list(xys[:,0])])
y = xys[:,1]

# Create polynomial features
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(X)

# Fit a linear regression model to the polynomial features
model_quad = LinearRegression()
model_quad.fit(x_poly, y)

# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

print(model_quad.coef_)
print(model_quad.intercept_)

slope = model.coef_[0]
intercept = model.intercept_

print("Slope:", slope)
print("Intercept:", intercept)

# Plot the data and the learned line
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
#plt.plot(X,[441.49 * x**2-2780.31*x+4577 for x in xys[:,0]]
plt.plot(X, model_quad.predict(x_poly), color='green')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
a.digraph.nodes
# Out:
# NodeView(([[1, 1]
# [0, 1], [1, 0]
# [3, 1], [1, 1]
# [0, 1], [1, 0]
# [3, 1]],))

# %%
import solomon.surface_group as sg
a.advance()

# %%
b = list(a.digraph.nodes)[5]

# %%
b((sg.FreeGrp(3).gens[0].artin_hom(b.domain))(sg.FreeGrp(4).gens[0]))
# Out:
# [2]

# %%
b.underlying_lst[0] ** 0 * b.underlying_lst[1]
# Out:
# [2, 1]
# [3, 0]
